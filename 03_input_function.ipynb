# %%
#input function
#to get user Input

# %%
name = input("Enter Your Name:")    #Dynamic Value
country = "Germany"                 #Hard-coded (Static) value
print(name, "comes from", country)
# Out:
# Shiny comes from Germany

# %%
#input makes our program interactive
#let our program ask question and react to what user types, makeing it feel alive

# %%
#Exercise covers Print, input, variables function
x = "A"
print(x)
#Ask for a value
y = input("Enter Value:")
print(y)
# Out:
# A
# B

# %%
#input() always returns a string — even if the user types a number
age = int(input("Enter your age: "))
print(age + 1)   # ❌ TypeError! age is "25" not 25
# Out:
# 26
