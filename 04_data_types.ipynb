# %%
#DataTypes
#python automatically detect datatypes
#Dynamic - Datatypes can change any time!

x = True #bool
y = 10   #int
z = "Hello" #str

# %%
#DataTypes Categories
#No value - None
#Single value (Primitive Types) - 50 (int), 3.14 (float), Hello (str), True (bool)
#Multi vales (Containers, Collections) - list, set, typle, diet (Containers, Collections)

# %%
#Exercise
a = 10 #int
b = 3.15 #float
c = "Hello" #str
d = 'Hi' #str
e = "1234" #str
f = True #bool (case-sensitive)
g = False #bool
h = None #No value
i = "" #str - black with no characters inside, but its not same as None!
j = " " #str - empty space

# %%
#Functions 
#Standalone functions - print(), input()
#Methods of Class - upper(), replace()
#Operations - Magic methods +- * / > < ==

#independent block of code
#function_name(value)

# %%
#Standard Library
#Built-in Module
#class str - upper(), replace()
#class int - to_byte()

# %%
#Methods
#Functions belong to objects/classes
#value.method_name()

# %%
#Examples

text = "hi"
number = 10

print(type(text))
print(type(number))

print(len(text)) #len work on str alone
#print(len(number)) 

print(text.upper()) #str methods
#print(number.upper()) 

print(number.bit_length()) #int methods
# Out:
# <class 'str'>
# <class 'int'>
# 2
# HI
# 4

# %%
#Summary
#Each value has a data type
#automatically detects data types
#Dynamic, can change anytime

#3 categories
#no value - None type
#single value - int, str, bool, float. complex
#multiple value - set, tuple, dict, list

# %%
#Challenge
#my age
#my height (decimels)
#my name
#am i student
#something with no value

#print the values, datatypes, length

age = 25
height = 160.0
name = "shiny"
student =True
nothing = None

#print values
print(age)
print(height)
print(name)
print(student)
print(nothing)

#datatypes
print(type(age))
print(type(height))
print(type(name))
print(type(student))
print(type(nothing))

#len
print(len(str(age)))
print(len(str(height)))
print(len(name))
print(len(str(student)))
print(len(str(nothing)))
# Out:
# 25
# 160.0
# shiny
# True
# None
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# 2
# 5
# 5
# 4
# 4
